# %%
# https://stable-baselines3.readthedocs.io/en/master/guide/rl.html
# https://spinningup.openai.com/en/latest/spinningup/rl_intro2.html#a-taxonomy-of-rl-algorithms

# %% [markdown]
# # 1. Import dependencies

# %%
# !pip install stable-baselines3[extra]

# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # 2. Load Environment

# %%
environment_name = "CartPole-v0"

# %%
env = gym.make(environment_name)
# Out:
# /usr/local/lib/python3.12/dist-packages/gymnasium/envs/registration.py:512: DeprecationWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.deprecation(

# %%
episodes = 5
for episode in range(1, episodes+1):
    state, info = env.reset()
    done = False
    score = 0

    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:39.0
# Episode:2 Score:10.0
# Episode:3 Score:19.0
# Episode:4 Score:27.0
# Episode:5 Score:30.0
# /usr/local/lib/python3.12/dist-packages/gymnasium/envs/classic_control/cartpole.py:250: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym.make("CartPole-v0", render_mode="rgb_array")
#   gym.logger.warn(

# %% [markdown]
# # Understanding The Environment
# https://github.com/openai/gym/blob/master/gym/envs/classic_control/cartpole.py

# %%
# 0-push cart to left, 1-push cart to the right
env.action_space.sample()
# Out:
# np.int64(1)

# %%
# [cart position, cart velocity, pole angle, pole angular velocity]
env.observation_space.sample()
# Out:
# array([-2.488046  , -0.7539723 ,  0.05570687, -0.9286005 ], dtype=float32)

# %% [markdown]
# # 3. Train an RL Model

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose = 1)
# Out:
# /usr/local/lib/python3.12/dist-packages/gymnasium/envs/registration.py:512: DeprecationWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.deprecation(
# Using cuda device
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
model.learn(total_timesteps=20000)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# -----------------------------
# | time/              |      |
# |    fps             | 562  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 431         |
# |    iterations           | 2           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009270524 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.685      |
# |    explained_variance   | -0.00528    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.69        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0164     |
# |    value_loss           | 50          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 441         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010728947 |
# |    clip_fraction        | 0.0814      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.0973      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.9        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0203     |
# |    value_loss           | 36.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 4            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0076458645 |
# |    clip_fraction        | 0.103        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.631       |
# |    explained_variance   | 0.242        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17           |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0207      |
# |    value_loss           | 52.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 5           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.006703875 |
# |    clip_fraction        | 0.0578      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.607      |
# |    explained_variance   | 0.29        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.7        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 61.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 6           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007263954 |
# |    clip_fraction        | 0.0751      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.595      |
# |    explained_variance   | 0.54        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.7        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 50.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 473         |
# |    iterations           | 7           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008732324 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.569      |
# |    explained_variance   | 0.559       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.9        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0172     |
# |    value_loss           | 61.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 477         |
# |    iterations           | 8           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007020632 |
# |    clip_fraction        | 0.0938      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.595      |
# |    explained_variance   | 0.743       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.16        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 38.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 475          |
# |    iterations           | 9            |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0067292983 |
# |    clip_fraction        | 0.0587       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.566       |
# |    explained_variance   | 0.771        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.3         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00553     |
# |    value_loss           | 31.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 477          |
# |    iterations           | 10           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0043679364 |
# |    clip_fraction        | 0.0211       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.576       |
# |    explained_variance   | 0.453        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.25         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00509     |
# |    value_loss           | 26           |
# ------------------------------------------

# %% [markdown]
# # 4. Save and Reload Model

# %%
import os
PPO_path = os.path.join('Training', 'Saved Models', 'PPO_model')

# %%
model.save(PPO_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1983978307.py in <cell line: 0>()
# ----> 1 model.save(PPO_path)
#
# NameError: name 'model' is not defined

# %%
del model

# %%
model = PPO.load('/content/Training/Saved Models/PPO_model.zip', env=env)
# Out:
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(

# %% [markdown]
# # 4. Evaluation

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/evaluation.py:70: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/vec_env/base_vec_env.py:259: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# (np.float64(200.0), np.float64(0.0))

# %%
env.close()

# %% [markdown]
# # 5. Test Model

# %%
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    env.render()
    if done:
        print('info', info)
        break
# Out:
# info [{'TimeLimit.truncated': True, 'terminal_observation': array([-0.17363684, -0.06195864,  0.03552374,  0.44321474], dtype=float32)}]

# %%
env.close()

# %% [markdown]
# # 6. Viewing Logs in Tensorboard

# %%
log_path="/content/Training"
training_log_path = os.path.join(log_path, 'PPO_3')

# %%
# !tensorboard --logdir={training_log_path}
# Out:
# /usr/local/lib/python3.12/dist-packages/tensorboard/_vendor/bleach/sanitizer.py:292: SyntaxWarning: invalid escape sequence '\s'
#   "[`\000-\040\177-\240\s]+",
# /usr/local/lib/python3.12/dist-packages/tensorboard/_vendor/bleach/sanitizer.py:339: SyntaxWarning: invalid escape sequence '\s'
#   style = re.compile('url\s*\(\s*[^\s)]+?\s*\)\s*').sub(' ', style)
# /usr/local/lib/python3.12/dist-packages/tensorboard/_vendor/bleach/sanitizer.py:354: SyntaxWarning: invalid escape sequence '\s'
#   if not re.match("^\s*([-\w]+\s*:[^:;]*(;\s*|$))*$", style):
# /usr/local/lib/python3.12/dist-packages/tensorboard/_vendor/bleach/sanitizer.py:358: SyntaxWarning: invalid escape sequence '\w'
#   for prop, value in re.findall('([-\w]+)\s*:\s*([^:;]*)', style):
# 2025-12-18 04:45:32.615492: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766033132.636126    2347 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766033132.642392    2347 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766033132.657908    2347 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766033132.657933    2347 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766033132.657937    2347 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766033132.657942    2347 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.19.0 at http://localhost:6006/ (Press CTRL+C to quit)
# Exception ignored in atexit callback: <function clean_up at 0x7ae151cf2b60>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/jax/_src/api.py", line 3173, in clean_up
#     clear_caches()
#   File "/usr/local/lib/python3.12/dist-packages/jax/_src/api.py", line 3196, in clear_caches
#     pjit._cpp_pjit_cache_explicit_attributes.clear()
# KeyboardInterrupt:

# %% [markdown]
# # 7. Adding a callback to the training Stage

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold
import os

# %%
save_path = os.path.join('Training', 'Saved Models')
log_path = os.path.join('Training', 'Logs')

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])
# Out:
# /usr/local/lib/python3.12/dist-packages/gymnasium/envs/registration.py:512: DeprecationWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.deprecation(

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=190, verbose=1)
eval_callback = EvalCallback(env,
                             callback_on_new_best=stop_callback,
                             eval_freq=10000,
                             best_model_save_path=save_path,
                             verbose=1)

# %%
model = PPO('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)
# Out:
# Using cuda device
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training/Logs/PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 783  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 626         |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008708074 |
# |    clip_fraction        | 0.0938      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.0016      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.94        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0124     |
# |    value_loss           | 56.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 565         |
# |    iterations           | 3           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009967497 |
# |    clip_fraction        | 0.066       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.668      |
# |    explained_variance   | 0.074       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0175     |
# |    value_loss           | 38.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 548          |
# |    iterations           | 4            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0068798377 |
# |    clip_fraction        | 0.0616       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.643       |
# |    explained_variance   | 0.188        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.4         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.017       |
# |    value_loss           | 58.2         |
# ------------------------------------------
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/evaluation.py:70: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | 200          |
# | time/                   |              |
# |    total_timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 0.0069757793 |
# |    clip_fraction        | 0.0689       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.614       |
# |    explained_variance   | 0.276        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.1         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0164      |
# |    value_loss           | 65.7         |
# ------------------------------------------
# New best mean reward!
# Stopping training because the mean reward 200.00 is above the threshold 190

# %%
model_path = os.path.join('Training', 'Saved Models', 'best_model')
model = PPO.load(model_path, env=env)

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/vec_env/base_vec_env.py:259: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# (np.float64(195.3), np.float64(10.714942836991712))

# %%
env.close()

# %% [markdown]
# # 8. Changing Policies

# %%
net_arch=[dict(pi=[128, 128, 128, 128], vf=[128, 128, 128, 128])]

# %%
model = PPO('MlpPolicy', env, verbose = 1, policy_kwargs={'net_arch': net_arch})
# Out:
# Using cuda device
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 664  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 492         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014539203 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.681      |
# |    explained_variance   | 0.00259     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.66        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0259     |
# |    value_loss           | 24.6        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 474        |
# |    iterations           | 3          |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01950079 |
# |    clip_fraction        | 0.239      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.644     |
# |    explained_variance   | 0.42       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 10.4       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0386    |
# |    value_loss           | 28.7       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 463         |
# |    iterations           | 4           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011617541 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.603      |
# |    explained_variance   | 0.475       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.5        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0248     |
# |    value_loss           | 42.9        |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.014959881 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.565      |
# |    explained_variance   | 0.418       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.3        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0181     |
# |    value_loss           | 46.5        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 428   |
# |    iterations      | 5     |
# |    time_elapsed    | 23    |
# |    total_timesteps | 10240 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 430         |
# |    iterations           | 6           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007347087 |
# |    clip_fraction        | 0.0697      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.538      |
# |    explained_variance   | 0.734       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.46        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 29.6        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 425          |
# |    iterations           | 7            |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0090243695 |
# |    clip_fraction        | 0.1          |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.511       |
# |    explained_variance   | 0.918        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.24         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00602     |
# |    value_loss           | 10.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 428          |
# |    iterations           | 8            |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0078223515 |
# |    clip_fraction        | 0.0859       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.51        |
# |    explained_variance   | 0.945        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.834        |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0113      |
# |    value_loss           | 6.96         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 428         |
# |    iterations           | 9           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.015055934 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.506      |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.666       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 4.81        |
# -----------------------------------------
# Eval num_timesteps=20000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 200        |
# |    mean_reward          | 200        |
# | time/                   |            |
# |    total_timesteps      | 20000      |
# | train/                  |            |
# |    approx_kl            | 0.01161252 |
# |    clip_fraction        | 0.0956     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.468     |
# |    explained_variance   | 0.944      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.183      |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0072    |
# |    value_loss           | 2.83       |
# ----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 419   |
# |    iterations      | 10    |
# |    time_elapsed    | 48    |
# |    total_timesteps | 20480 |
# ------------------------------

# %% [markdown]
# # 9. Using an Alternate Algorithm

# %%
from stable_baselines3 import DQN

# %%
model = DQN('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)
# Out:
# Using cuda device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training/Logs/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 6569     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 90       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.915    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1586     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 178      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.505    |
# |    n_updates        | 19       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1451     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 238      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.471    |
# |    n_updates        | 34       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.83     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1361     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 357      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.4      |
# |    n_updates        | 64       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.79     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1307     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 442      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.379    |
# |    n_updates        | 85       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.768    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1280     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 489      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.318    |
# |    n_updates        | 97       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.742    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1248     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 543      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.327    |
# |    n_updates        | 110      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.714    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1232     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 603      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.261    |
# |    n_updates        | 125      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.683    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1225     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 668      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.232    |
# |    n_updates        | 141      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.644    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1204     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 750      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.196    |
# |    n_updates        | 162      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.611    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1195     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 818      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.196    |
# |    n_updates        | 179      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.583    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1187     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 877      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.178    |
# |    n_updates        | 194      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.551    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1178     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 946      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.183    |
# |    n_updates        | 211      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.519    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1168     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1012     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.134    |
# |    n_updates        | 227      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.486    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1156     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1082     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.108    |
# |    n_updates        | 245      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.462    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1149     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1132     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.105    |
# |    n_updates        | 257      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.436    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1140     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1187     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0903   |
# |    n_updates        | 271      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.415    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1133     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1232     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0854   |
# |    n_updates        | 282      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.392    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1117     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1281     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0859   |
# |    n_updates        | 295      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.368    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1111     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1331     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.086    |
# |    n_updates        | 307      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.347    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1105     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1374     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0556   |
# |    n_updates        | 318      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.324    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1097     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1423     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.066    |
# |    n_updates        | 330      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.3      |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1086     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1474     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0491   |
# |    n_updates        | 343      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.278    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1080     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1519     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.049    |
# |    n_updates        | 354      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.257    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1069     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1564     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0486   |
# |    n_updates        | 365      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.236    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1063     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1608     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0385   |
# |    n_updates        | 376      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.212    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1058     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1659     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0323   |
# |    n_updates        | 389      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.191    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1053     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1704     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0316   |
# |    n_updates        | 400      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.167    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1045     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1753     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0395   |
# |    n_updates        | 413      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.145    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1040     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1801     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0414   |
# |    n_updates        | 425      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.125    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1037     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1842     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0176   |
# |    n_updates        | 435      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.105    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1030     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1885     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0144   |
# |    n_updates        | 446      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0828   |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1027     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1931     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0348   |
# |    n_updates        | 457      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0605   |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1021     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1978     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0251   |
# |    n_updates        | 469      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1016     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2019     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0191   |
# |    n_updates        | 479      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1011     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2062     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0163   |
# |    n_updates        | 490      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1007     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2112     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0172   |
# |    n_updates        | 502      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1001     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2160     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00784  |
# |    n_updates        | 514      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 996      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2206     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0134   |
# |    n_updates        | 526      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 994      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2247     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0119   |
# |    n_updates        | 536      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 990      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2291     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00683  |
# |    n_updates        | 547      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 986      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2337     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0117   |
# |    n_updates        | 559      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 983      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2378     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0104   |
# |    n_updates        | 569      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 976      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2423     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00941  |
# |    n_updates        | 580      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 974      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2466     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00659  |
# |    n_updates        | 591      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 971      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2515     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00558  |
# |    n_updates        | 603      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 965      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2557     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0042   |
# |    n_updates        | 614      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 962      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2601     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00418  |
# |    n_updates        | 625      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 959      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2645     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00637  |
# |    n_updates        | 636      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 958      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2692     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00761  |
# |    n_updates        | 647      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 954      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2741     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00388  |
# |    n_updates        | 660      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 952      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2783     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00425  |
# |    n_updates        | 670      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 951      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2828     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0186   |
# |    n_updates        | 681      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 947      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2871     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0052   |
# |    n_updates        | 692      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 945      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2914     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00325  |
# |    n_updates        | 703      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 943      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2957     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000986 |
# |    n_updates        | 714      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 941      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3002     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00207  |
# |    n_updates        | 725      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 940      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3051     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00351  |
# |    n_updates        | 737      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 938      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3099     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00443  |
# |    n_updates        | 749      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 936      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3149     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00106  |
# |    n_updates        | 762      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 935      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3195     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00165  |
# |    n_updates        | 773      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 933      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3243     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00225  |
# |    n_updates        | 785      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 930      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3298     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0115   |
# |    n_updates        | 799      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 929      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3344     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00122  |
# |    n_updates        | 810      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 927      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3399     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00227  |
# |    n_updates        | 824      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 926      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3448     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00223  |
# |    n_updates        | 836      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 924      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3498     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00131  |
# |    n_updates        | 849      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 923      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3552     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00135  |
# |    n_updates        | 862      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 922      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3596     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00298  |
# |    n_updates        | 873      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 921      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3647     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000422 |
# |    n_updates        | 886      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 921      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3690     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00115  |
# |    n_updates        | 897      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 918      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3741     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000557 |
# |    n_updates        | 910      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 909      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3790     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00226  |
# |    n_updates        | 922      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 903      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3837     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00163  |
# |    n_updates        | 934      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 900      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3888     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000687 |
# |    n_updates        | 946      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 896      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3940     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000765 |
# |    n_updates        | 959      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 892      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3993     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000922 |
# |    n_updates        | 973      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 887      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4042     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000524 |
# |    n_updates        | 985      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 883      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4097     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000339 |
# |    n_updates        | 999      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 880      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4159     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00314  |
# |    n_updates        | 1014     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 876      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4214     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000562 |
# |    n_updates        | 1028     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 872      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4275     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000215 |
# |    n_updates        | 1043     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 868      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4336     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00158  |
# |    n_updates        | 1058     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 865      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4393     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000657 |
# |    n_updates        | 1073     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 862      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4452     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000177 |
# |    n_updates        | 1087     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 860      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4507     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00056  |
# |    n_updates        | 1101     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 858      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4572     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000469 |
# |    n_updates        | 1117     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 856      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4632     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000458 |
# |    n_updates        | 1132     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 851      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4697     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00105  |
# |    n_updates        | 1149     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 847      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4760     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000311 |
# |    n_updates        | 1164     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 843      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4825     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000682 |
# |    n_updates        | 1181     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 837      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4891     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000738 |
# |    n_updates        | 1197     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 833      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4951     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000444 |
# |    n_updates        | 1212     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 828      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5016     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000787 |
# |    n_updates        | 1228     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 826      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5081     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00964  |
# |    n_updates        | 1245     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 826      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5149     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000257 |
# |    n_updates        | 1262     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 827      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5223     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000384 |
# |    n_updates        | 1280     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 826      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5293     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000198 |
# |    n_updates        | 1298     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 827      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5369     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00106  |
# |    n_updates        | 1317     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 826      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5449     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000214 |
# |    n_updates        | 1337     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 823      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5522     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000266 |
# |    n_updates        | 1355     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 823      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5587     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000137 |
# |    n_updates        | 1371     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 823      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5663     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000852 |
# |    n_updates        | 1390     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 823      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5728     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000255 |
# |    n_updates        | 1406     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 823      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 5802     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000143 |
# |    n_updates        | 1425     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 823      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 5882     |
# | train/              |          |
# ...
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1164     |
# |    fps              | 797      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 17885    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0317   |
# |    n_updates        | 4446     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1168     |
# |    fps              | 797      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 17945    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0238   |
# |    n_updates        | 4461     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1172     |
# |    fps              | 797      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 18000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00316  |
# |    n_updates        | 4474     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1176     |
# |    fps              | 797      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 18067    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0188   |
# |    n_updates        | 4491     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1180     |
# |    fps              | 797      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 18116    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0237   |
# |    n_updates        | 4503     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1184     |
# |    fps              | 797      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 18155    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0292   |
# |    n_updates        | 4513     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1188     |
# |    fps              | 797      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 18192    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0295   |
# |    n_updates        | 4522     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1192     |
# |    fps              | 797      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 18242    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0335   |
# |    n_updates        | 4535     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1196     |
# |    fps              | 797      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 18297    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0109   |
# |    n_updates        | 4549     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1200     |
# |    fps              | 798      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 18366    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0304   |
# |    n_updates        | 4566     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1204     |
# |    fps              | 798      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 18438    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0255   |
# |    n_updates        | 4584     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1208     |
# |    fps              | 798      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 18518    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.029    |
# |    n_updates        | 4604     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1212     |
# |    fps              | 797      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 18581    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0184   |
# |    n_updates        | 4620     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1216     |
# |    fps              | 797      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 18623    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0197   |
# |    n_updates        | 4630     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1220     |
# |    fps              | 797      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 18676    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0177   |
# |    n_updates        | 4643     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1224     |
# |    fps              | 798      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 18750    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0175   |
# |    n_updates        | 4662     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1228     |
# |    fps              | 797      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 18837    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0261   |
# |    n_updates        | 4684     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1232     |
# |    fps              | 798      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 18902    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0192   |
# |    n_updates        | 4700     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1236     |
# |    fps              | 798      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 18952    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.02     |
# |    n_updates        | 4712     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1240     |
# |    fps              | 798      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 18994    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0201   |
# |    n_updates        | 4723     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1244     |
# |    fps              | 798      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 19052    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0254   |
# |    n_updates        | 4737     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1248     |
# |    fps              | 798      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 19138    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0249   |
# |    n_updates        | 4759     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1252     |
# |    fps              | 798      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 19205    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0307   |
# |    n_updates        | 4776     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1256     |
# |    fps              | 797      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 19263    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0205   |
# |    n_updates        | 4790     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1260     |
# |    fps              | 797      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 19340    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0441   |
# |    n_updates        | 4809     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1264     |
# |    fps              | 797      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 19441    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0399   |
# |    n_updates        | 4835     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1268     |
# |    fps              | 797      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 19505    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0235   |
# |    n_updates        | 4851     |
# ----------------------------------
# Eval num_timesteps=19520, episode_reward=15.00 +/- 1.41
# Episode length: 15.00 +/- 1.41
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 15       |
# |    mean_reward      | 15       |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 19520    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0136   |
# |    n_updates        | 4854     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1272     |
# |    fps              | 796      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 19569    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0215   |
# |    n_updates        | 4867     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1276     |
# |    fps              | 796      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 19642    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0164   |
# |    n_updates        | 4885     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1280     |
# |    fps              | 796      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 19713    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0152   |
# |    n_updates        | 4903     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1284     |
# |    fps              | 796      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 19788    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00548  |
# |    n_updates        | 4921     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1288     |
# |    fps              | 796      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 19855    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0253   |
# |    n_updates        | 4938     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1292     |
# |    fps              | 796      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 19930    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0165   |
# |    n_updates        | 4957     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1296     |
# |    fps              | 796      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 19986    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0164   |
# |    n_updates        | 4971     |
# ----------------------------------

# %%
dqn_path = os.path.join('Training', 'Saved Models', 'DQN_model')

# %%
model.save(dqn_path)

# %%
model = DQN.load(dqn_path, env=env)

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# (np.float64(12.4), np.float64(1.3564659966250536))

# %%
env.close()
